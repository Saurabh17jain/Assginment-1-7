# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## QUES 1

# %%
customer=pd.read_csv("/content/AWCustomers.csv")

# %%
customer.head()
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# 1  Partial College        Clerical      M             M             1
# 2        Bachelors        Clerical      F             S             0
# 3  Partial College  Skilled Manual      M             M             1
# 4  Partial College  Skilled Manual      M             S             1
#
#   NumberCarsOwned NumberChildrenAtHome TotalChildren  YearlyIncome  \
# 0               3                    0             1         81916
# 1               2                    1             2         81076
# 2               3                    0             0         86387
# 3               2                    1             2         61481
# 4               1                    0             0         51804
#
#    LastUpdated
# 0   2017-03-06
# 1   2017-03-06
# 2   2017-03-06
# 3   2017-03-06
# 4   2017-03-06
#
# [5 rows x 24 columns]

# %%
customer=customer.drop("Title", axis=1)

# %%
customer = customer.drop("Suffix", axis=1)
customer = customer.drop("AddressLine2", axis=1)
customer = customer.drop("LastUpdated", axis=1)
customer = customer.drop("Education", axis=1)

# %%
updated_customer=customer

# %%
updated_customer.head()
# Out:
#    CustomerID FirstName MiddleName  LastName            AddressLine1  \
# 0       21173      Chad          C      Yuan      7090 C. Mount Hood
# 1       13249      Ryan        NaN     Perry     3651 Willow Lake Rd
# 2       29350     Julia        NaN  Thompson  1774 Tice Valley Blvd.
# 3       13503  Theodore        NaN     Gomez         2103 Baldwin Dr
# 4       22803  Marshall          J      Shan         Am Gallberg 234
#
#           City    StateProvinceName CountryRegionName PostalCode  \
# 0   Wollongong      New South Wales         Australia       2500
# 1      Shawnee     British Columbia            Canada    V9B 2C3
# 2  West Covina           California     United States      91791
# 3    Liverpool              England    United Kingdom     L4 4HB
# 4        Werne  Nordrhein-Westfalen           Germany      59368
#
#            PhoneNumber   BirthDate      Occupation Gender MaritalStatus  \
# 0  1 (11) 500 555-0115  1987-11-13        Clerical      M             M
# 1         787-555-0136  1972-07-21        Clerical      M             M
# 2         120-555-0111  1985-11-09        Clerical      F             S
# 3  1 (11) 500 555-0167  1977-10-18  Skilled Manual      M             M
# 4  1 (11) 500 555-0113  1975-02-05  Skilled Manual      M             S
#
#    HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  TotalChildren  \
# 0              1                3                     0              1
# 1              1                2                     1              2
# 2              0                3                     0              0
# 3              1                2                     1              2
# 4              1                1                     0              0
#
#    YearlyIncome
# 0         81916
# 1         81076
# 2         86387
# 3         61481
# 4         51804

# %%
updated_customer.describe()
# Out:
#          CustomerID  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# count  18361.000000   18361.000000     18361.000000          18361.000000
# mean   20241.987092       0.610588         1.270301              0.338162
# std     5336.332731       0.487630         0.913989              0.568957
# min    11000.000000       0.000000         0.000000              0.000000
# 25%    15621.000000       0.000000         1.000000              0.000000
# 50%    20248.000000       1.000000         1.000000              0.000000
# 75%    24863.000000       1.000000         2.000000              1.000000
# max    29483.000000       1.000000         5.000000              3.000000
#
#        TotalChildren   YearlyIncome
# count   18361.000000   18361.000000
# mean        0.850389   72754.779642
# std         0.927315   30686.014313
# min         0.000000   25435.000000
# 25%         0.000000   53312.000000
# 50%         0.000000   61851.000000
# 75%         2.000000   87410.000000
# max         3.000000  139115.000000

# %%
updated_customer.describe(include='all')
# Out:
#           CustomerID  FirstName MiddleName LastName       AddressLine1  \
# count   18361.000000      18361      10572    18361              18361
# unique           NaN        670         44      375              12742
# top              NaN  Katherine          A     Diaz  Attaché de Presse
# freq             NaN         97       1287      209                 17
# mean    20241.987092        NaN        NaN      NaN                NaN
# std      5336.332731        NaN        NaN      NaN                NaN
# min     11000.000000        NaN        NaN      NaN                NaN
# 25%     15621.000000        NaN        NaN      NaN                NaN
# 50%     20248.000000        NaN        NaN      NaN                NaN
# 75%     24863.000000        NaN        NaN      NaN                NaN
# max     29483.000000        NaN        NaN      NaN                NaN
#
#           City StateProvinceName CountryRegionName PostalCode  \
# count    18361             18361             18361      18361
# unique     269                54                 6        323
# top     London        California     United States      98168
# freq       420              4410              7770        212
# mean       NaN               NaN               NaN        NaN
# std        NaN               NaN               NaN        NaN
# min        NaN               NaN               NaN        NaN
# 25%        NaN               NaN               NaN        NaN
# 50%        NaN               NaN               NaN        NaN
# 75%        NaN               NaN               NaN        NaN
# max        NaN               NaN               NaN        NaN
#
#                 PhoneNumber   BirthDate      Occupation Gender MaritalStatus  \
# count                 18361       18361           18361  18361         18361
# unique                 8836        8230               5      2             2
# top     1 (11) 500 555-0118  1987-05-14  Skilled Manual      M             M
# freq                    204          11            6059   9287          9947
# mean                    NaN         NaN             NaN    NaN           NaN
# std                     NaN         NaN             NaN    NaN           NaN
# min                     NaN         NaN             NaN    NaN           NaN
# 25%                     NaN         NaN             NaN    NaN           NaN
# 50%                     NaN         NaN             NaN    NaN           NaN
# 75%                     NaN         NaN             NaN    NaN           NaN
# max                     NaN         NaN             NaN    NaN           NaN
#
#         HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  TotalChildren  \
# count    18361.000000     18361.000000          18361.000000   18361.000000
# unique            NaN              NaN                   NaN            NaN
# top               NaN              NaN                   NaN            NaN
# freq              NaN              NaN                   NaN            NaN
# mean         0.610588         1.270301              0.338162       0.850389
# std          0.487630         0.913989              0.568957       0.927315
# min          0.000000         0.000000              0.000000       0.000000
# 25%          0.000000         1.000000              0.000000       0.000000
# 50%          1.000000         1.000000              0.000000       0.000000
# 75%          1.000000         2.000000              1.000000       2.000000
# max          1.000000         5.000000              3.000000       3.000000
#
#          YearlyIncome
# count    18361.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean     72754.779642
# std      30686.014313
# min      25435.000000
# 25%      53312.000000
# 50%      61851.000000
# 75%      87410.000000
# max     139115.000000

# %%
updated_customer=updated_customer.drop("PhoneNumber", axis=1)

# %%
updated_customer.tail()
# Out:
#        CustomerID FirstName MiddleName LastName            AddressLine1  \
# 18356       25414     Grace          C   Bailey      6627 Camelback Ct.
# 18357       11459     Tasha        NaN     Deng         9627 Kendall Rd
# 18358       12160    Jaclyn        NaN    Zhang       4364 Viera Avenue
# 18359       14353      Erin          I     Reed  3866 Mt. Everest Court
# 18360       16676    Amanda        NaN    Perry     7870 Orangewood Dr.
#
#                  City StateProvinceName CountryRegionName PostalCode  \
# 18356        Coronado        California     United States      92118
# 18357  Port Macquarie   New South Wales         Australia       2444
# 18358       Beaverton            Oregon     United States      97005
# 18359       Vancouver  British Columbia            Canada    V7L 4J4
# 18360       Grossmont        California     United States      91941
#
#         BirthDate      Occupation Gender MaritalStatus  HomeOwnerFlag  \
# 18356  1990-11-11  Skilled Manual      F             M              0
# 18357  1992-10-13  Skilled Manual      F             S              0
# 18358  1983-11-24  Skilled Manual      F             S              0
# 18359  1995-06-15        Clerical      F             S              0
# 18360  1986-03-26    Professional      F             M              1
#
#        NumberCarsOwned  NumberChildrenAtHome  TotalChildren  YearlyIncome
# 18356                1                     0              2         52953
# 18357                2                     0              0         60992
# 18358                2                     0              0         51859
# 18359                0                     0              0         87177
# 18360                2                     0              0        136856

# %%
updated_customer=updated_customer.drop(["MiddleName", "LastName", "FirstName"], axis=1)

# %%
updated_customer.head()
# Out:
#    CustomerID            AddressLine1         City    StateProvinceName  \
# 0       21173      7090 C. Mount Hood   Wollongong      New South Wales
# 1       13249     3651 Willow Lake Rd      Shawnee     British Columbia
# 2       29350  1774 Tice Valley Blvd.  West Covina           California
# 3       13503         2103 Baldwin Dr    Liverpool              England
# 4       22803         Am Gallberg 234        Werne  Nordrhein-Westfalen
#
#   CountryRegionName PostalCode   BirthDate      Occupation Gender  \
# 0         Australia       2500  1987-11-13        Clerical      M
# 1            Canada    V9B 2C3  1972-07-21        Clerical      M
# 2     United States      91791  1985-11-09        Clerical      F
# 3    United Kingdom     L4 4HB  1977-10-18  Skilled Manual      M
# 4           Germany      59368  1975-02-05  Skilled Manual      M
#
#   MaritalStatus  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# 0             M              1                3                     0
# 1             M              1                2                     1
# 2             S              0                3                     0
# 3             M              1                2                     1
# 4             S              1                1                     0
#
#    TotalChildren  YearlyIncome
# 0              1         81916
# 1              2         81076
# 2              0         86387
# 3              2         61481
# 4              0         51804

# %%
updated_customer.to_csv("AWUpdated.csv")

# %% [markdown]
# ## Ques 2

# %%
pd.isna(updated_customer).head()
# Out:
#    CustomerID  AddressLine1   City  StateProvinceName  CountryRegionName  \
# 0       False         False  False              False              False
# 1       False         False  False              False              False
# 2       False         False  False              False              False
# 3       False         False  False              False              False
# 4       False         False  False              False              False
#
#    PostalCode  BirthDate  Occupation  Gender  MaritalStatus  HomeOwnerFlag  \
# 0       False      False       False   False          False          False
# 1       False      False       False   False          False          False
# 2       False      False       False   False          False          False
# 3       False      False       False   False          False          False
# 4       False      False       False   False          False          False
#
#    NumberCarsOwned  NumberChildrenAtHome  TotalChildren  YearlyIncome
# 0            False                 False          False         False
# 1            False                 False          False         False
# 2            False                 False          False         False
# 3            False                 False          False         False
# 4            False                 False          False         False

# %%
updated_customer.dropna()
# Out:
#        CustomerID            AddressLine1            City  \
# 0           21173      7090 C. Mount Hood      Wollongong
# 1           13249     3651 Willow Lake Rd         Shawnee
# 2           29350  1774 Tice Valley Blvd.     West Covina
# 3           13503         2103 Baldwin Dr       Liverpool
# 4           22803         Am Gallberg 234           Werne
# ...           ...                     ...             ...
# 18356       25414      6627 Camelback Ct.        Coronado
# 18357       11459         9627 Kendall Rd  Port Macquarie
# 18358       12160       4364 Viera Avenue       Beaverton
# 18359       14353  3866 Mt. Everest Court       Vancouver
# 18360       16676     7870 Orangewood Dr.       Grossmont
#
#          StateProvinceName CountryRegionName PostalCode   BirthDate  \
# 0          New South Wales         Australia       2500  1987-11-13
# 1         British Columbia            Canada    V9B 2C3  1972-07-21
# 2               California     United States      91791  1985-11-09
# 3                  England    United Kingdom     L4 4HB  1977-10-18
# 4      Nordrhein-Westfalen           Germany      59368  1975-02-05
# ...                    ...               ...        ...         ...
# 18356           California     United States      92118  1990-11-11
# 18357      New South Wales         Australia       2444  1992-10-13
# 18358               Oregon     United States      97005  1983-11-24
# 18359     British Columbia            Canada    V7L 4J4  1995-06-15
# 18360           California     United States      91941  1986-03-26
#
#            Occupation Gender MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0            Clerical      M             M              1                3
# 1            Clerical      M             M              1                2
# 2            Clerical      F             S              0                3
# 3      Skilled Manual      M             M              1                2
# 4      Skilled Manual      M             S              1                1
# ...               ...    ...           ...            ...              ...
# 18356  Skilled Manual      F             M              0                1
# 18357  Skilled Manual      F             S              0                2
# 18358  Skilled Manual      F             S              0                2
# 18359        Clerical      F             S              0                0
# 18360    Professional      F             M              1                2
#
#        NumberChildrenAtHome  TotalChildren  YearlyIncome
# 0                         0              1         81916
# 1                         1              2         81076
# 2                         0              0         86387
# 3                         1              2         61481
# 4                         0              0         51804
# ...                     ...            ...           ...
# 18356                     0              2         52953
# 18357                     0              0         60992
# 18358                     0              0         51859
# 18359                     0              0         87177
# 18360                     0              0        136856
#
# [18361 rows x 15 columns]

# %%
updated_customer['Gender'] = updated_customer['Gender'].replace({'M': 1, 'F': 0})
updated_customer.head()
# Out:
#    CustomerID            AddressLine1         City    StateProvinceName  \
# 0       21173      7090 C. Mount Hood   Wollongong      New South Wales
# 1       13249     3651 Willow Lake Rd      Shawnee     British Columbia
# 2       29350  1774 Tice Valley Blvd.  West Covina           California
# 3       13503         2103 Baldwin Dr    Liverpool              England
# 4       22803         Am Gallberg 234        Werne  Nordrhein-Westfalen
#
#   CountryRegionName PostalCode   BirthDate      Occupation  Gender  \
# 0         Australia       2500  1987-11-13        Clerical       1
# 1            Canada    V9B 2C3  1972-07-21        Clerical       1
# 2     United States      91791  1985-11-09        Clerical       0
# 3    United Kingdom     L4 4HB  1977-10-18  Skilled Manual       1
# 4           Germany      59368  1975-02-05  Skilled Manual       1
#
#   MaritalStatus  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# 0             M              1                3                     0
# 1             M              1                2                     1
# 2             S              0                3                     0
# 3             M              1                2                     1
# 4             S              1                1                     0
#
#    TotalChildren  YearlyIncome
# 0              1         81916
# 1              2         81076
# 2              0         86387
# 3              2         61481
# 4              0         51804

# %%
updated_customer['MaritalStatus'] = updated_customer['MaritalStatus'].replace({'M': 1, 'S': 0})
updated_customer.head()
# Out:
#    CustomerID            AddressLine1         City    StateProvinceName  \
# 0       21173      7090 C. Mount Hood   Wollongong      New South Wales
# 1       13249     3651 Willow Lake Rd      Shawnee     British Columbia
# 2       29350  1774 Tice Valley Blvd.  West Covina           California
# 3       13503         2103 Baldwin Dr    Liverpool              England
# 4       22803         Am Gallberg 234        Werne  Nordrhein-Westfalen
#
#   CountryRegionName PostalCode   BirthDate      Occupation  Gender  \
# 0         Australia       2500  1987-11-13        Clerical       1
# 1            Canada    V9B 2C3  1972-07-21        Clerical       1
# 2     United States      91791  1985-11-09        Clerical       0
# 3    United Kingdom     L4 4HB  1977-10-18  Skilled Manual       1
# 4           Germany      59368  1975-02-05  Skilled Manual       1
#
#    MaritalStatus  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# 0              1              1                3                     0
# 1              1              1                2                     1
# 2              0              0                3                     0
# 3              1              1                2                     1
# 4              0              1                1                     0
#
#    TotalChildren  YearlyIncome
# 0              1         81916
# 1              2         81076
# 2              0         86387
# 3              2         61481
# 4              0         51804

# %%
updated_customer=updated_customer.drop("CountryRegionName", axis=1)
updated_customer=updated_customer.drop("AddressLine1", axis=1)
updated_customer.head()
# Out:
#    CustomerID         City    StateProvinceName PostalCode      Occupation  \
# 0       21173   Wollongong      New South Wales       2500        Clerical
# 1       13249      Shawnee     British Columbia    V9B 2C3        Clerical
# 2       29350  West Covina           California      91791        Clerical
# 3       13503    Liverpool              England     L4 4HB  Skilled Manual
# 4       22803        Werne  Nordrhein-Westfalen      59368  Skilled Manual
#
#    Gender  MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0       1              1              1                3
# 1       1              1              1                2
# 2       0              0              0                3
# 3       1              1              1                2
# 4       1              0              1                1
#
#    NumberChildrenAtHome  TotalChildren  YearlyIncome
# 0                     0              1         81916
# 1                     1              2         81076
# 2                     0              0         86387
# 3                     1              2         61481
# 4                     0              0         51804

# %%
updated_customer=updated_customer.drop("PostalCode", axis=1)
updated_customer.head()
# Out:
#    CustomerID         City    StateProvinceName      Occupation  Gender  \
# 0       21173   Wollongong      New South Wales        Clerical       1
# 1       13249      Shawnee     British Columbia        Clerical       1
# 2       29350  West Covina           California        Clerical       0
# 3       13503    Liverpool              England  Skilled Manual       1
# 4       22803        Werne  Nordrhein-Westfalen  Skilled Manual       1
#
#    MaritalStatus  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# 0              1              1                3                     0
# 1              1              1                2                     1
# 2              0              0                3                     0
# 3              1              1                2                     1
# 4              0              1                1                     0
#
#    TotalChildren  YearlyIncome
# 0              1         81916
# 1              2         81076
# 2              0         86387
# 3              2         61481
# 4              0         51804

# %%
encoded_data=pd.get_dummies(updated_customer)

# %%
encoded_data.head()
# Out:
#    CustomerID  Gender  MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0       21173       1              1              1                3
# 1       13249       1              1              1                2
# 2       29350       0              0              0                3
# 3       13503       1              1              1                2
# 4       22803       1              0              1                1
#
#    NumberChildrenAtHome  TotalChildren  YearlyIncome  City_Ballard  \
# 0                     0              1         81916         False
# 1                     1              2         81076         False
# 2                     0              0         86387         False
# 3                     1              2         61481         False
# 4                     0              0         51804         False
#
#    City_Baltimore  ...  StateProvinceName_Victoria  \
# 0           False  ...                       False
# 1           False  ...                       False
# 2           False  ...                       False
# 3           False  ...                       False
# 4           False  ...                       False
#
#    StateProvinceName_Virginia  StateProvinceName_Washington  \
# 0                       False                         False
# 1                       False                         False
# 2                       False                         False
# 3                       False                         False
# 4                       False                         False
#
#    StateProvinceName_Wyoming  StateProvinceName_Yveline  Occupation_Clerical  \
# 0                      False                      False                 True
# 1                      False                      False                 True
# 2                      False                      False                 True
# 3                      False                      False                False
# 4                      False                      False                False
#
#    Occupation_Management  Occupation_Manual  Occupation_Professional  \
# 0                  False              False                    False
# 1                  False              False                    False
# 2                  False              False                    False
# 3                  False              False                    False
# 4                  False              False                    False
#
#    Occupation_Skilled Manual
# 0                      False
# 1                      False
# 2                      False
# 3                       True
# 4                       True
#
# [5 rows x 336 columns]

# %% [markdown]
# ## Ques 3

# %%
def jaccard_similarity(set1, set2):
    set1 = set(set1)
    set2 = set(set2)

    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))

    return intersection / union if union != 0 else 0  
set1 = encoded_data.MaritalStatus
set2 = encoded_data.NumberCarsOwned
similarity = jaccard_similarity(set1, set2)
print("Jaccard Similarity:", similarity)
# Out:
# Jaccard Similarity: 0.3333333333333333

# %%
from numpy.linalg import norm
A = encoded_data.NumberCarsOwned
B = encoded_data.TotalChildren
cosine = np.dot(A,B)/(norm(A)*norm(B))
print("Cosine Similarity:", cosine)
# Out:
# Cosine Similarity: 0.5617361741434632

# %%
encoded_data.corr()
# Out:
#                            CustomerID    Gender  MaritalStatus  HomeOwnerFlag  \
# CustomerID                   1.000000  0.013270      -0.071044      -0.029199
# Gender                       0.013270  1.000000       0.042809       0.009935
# MaritalStatus               -0.071044  0.042809       1.000000       0.442841
# HomeOwnerFlag               -0.029199  0.009935       0.442841       1.000000
# NumberCarsOwned             -0.012101  0.003541       0.051823       0.209787
# ...                               ...       ...            ...            ...
# Occupation_Clerical         -0.006030 -0.000735       0.001439       0.040706
# Occupation_Management       -0.008868 -0.013094       0.037294       0.190383
# Occupation_Manual            0.024769  0.011222      -0.014242      -0.213904
# Occupation_Professional     -0.022005  0.004709       0.028880       0.224440
# Occupation_Skilled Manual    0.005141 -0.001308      -0.035670      -0.142416
#
#                            NumberCarsOwned  NumberChildrenAtHome  \
# CustomerID                       -0.012101             -0.039706
# Gender                            0.003541              0.014645
# MaritalStatus                     0.051823              0.471534
# HomeOwnerFlag                     0.209787              0.368459
# NumberCarsOwned                   1.000000              0.020393
# ...                                    ...                   ...
# Occupation_Clerical               0.183281              0.003446
# Occupation_Management             0.242365              0.013343
# Occupation_Manual                -0.379733              0.002230
# Occupation_Professional           0.203863             -0.004095
# Occupation_Skilled Manual        -0.163579             -0.012811
#
#                            TotalChildren  YearlyIncome  City_Ballard  \
# CustomerID                     -0.071245     -0.029423     -0.000103
# Gender                          0.030360     -0.000354      0.003814
# MaritalStatus                   0.750911      0.048784     -0.000538
# HomeOwnerFlag                   0.578197      0.356243     -0.001685
# NumberCarsOwned                 0.030430      0.477300      0.012739
# ...                                  ...           ...           ...
# Occupation_Clerical             0.007238      0.171413     -0.000609
# Occupation_Management           0.007872      0.487918     -0.021001
# Occupation_Manual              -0.009819     -0.642032     -0.007747
# Occupation_Professional         0.015569      0.608608     -0.002718
# Occupation_Skilled Manual      -0.013929     -0.368936      0.024762
#
#                            City_Baltimore  ...  StateProvinceName_Victoria  \
# CustomerID                      -0.009815  ...                   -0.008878
# Gender                           0.007295  ...                    0.014384
# MaritalStatus                    0.006788  ...                    0.002234
# HomeOwnerFlag                   -0.009241  ...                   -0.005626
# NumberCarsOwned                 -0.002183  ...                    0.003526
# ...                                   ...  ...                         ...
# Occupation_Clerical              0.013022  ...                    0.005242
# Occupation_Management           -0.003169  ...                    0.002535
# Occupation_Manual               -0.003504  ...                   -0.004262
# Occupation_Professional         -0.002283  ...                   -0.003248
# Occupation_Skilled Manual       -0.005179  ...                   -0.001275
#
#                            StateProvinceName_Virginia  \
# CustomerID                                  -0.002369
# Gender                                       0.007295
# MaritalStatus                               -0.008024
# HomeOwnerFlag                                0.005894
# NumberCarsOwned                              0.005892
# ...                                               ...
# Occupation_Clerical                          0.013022
# Occupation_Management                       -0.003169
# Occupation_Manual                           -0.003504
# Occupation_Professional                     -0.002283
# Occupation_Skilled Manual                   -0.005179
#
#                            StateProvinceName_Washington  \
# CustomerID                                    -0.002599
# Gender                                        -0.000025
# MaritalStatus                                  0.021952
# HomeOwnerFlag                                  0.033265
# NumberCarsOwned                                0.019383
# ...                                                 ...
# Occupation_Clerical                            0.020892
# Occupation_Management                         -0.002220
# Occupation_Manual                             -0.009665
# Occupation_Professional                        0.012473
# Occupation_Skilled Manual                     -0.016873
#
#                            StateProvinceName_Wyoming  \
# CustomerID                                 -0.007064
# Gender                                     -0.000121
# MaritalStatus                               0.009599
# HomeOwnerFlag                               0.008335
# NumberCarsOwned                             0.008333
# ...                                              ...
# Occupation_Clerical                        -0.005916
# Occupation_Management                      -0.004481
# Occupation_Manual                          -0.004955
# Occupation_Professional                     0.033747
# Occupation_Skilled Manual                  -0.007325
#
#                            StateProvinceName_Yveline  Occupation_Clerical  \
# CustomerID                                  0.003103            -0.006030
# Gender                                      0.004646            -0.000735
# MaritalStatus                              -0.040338             0.001439
# HomeOwnerFlag                              -0.039363             0.040706
# NumberCarsOwned                            -0.009991             0.183281
# ...                                              ...                  ...
# Occupation_Clerical                        -0.009870             1.000000
# Occupation_Management                      -0.014029            -0.243346
# Occupation_Manual                           0.009608            -0.269063
# Occupation_Professional                    -0.015273            -0.175290
# Occupation_Skilled Manual                   0.021074            -0.397754
#
#                            Occupation_Management  Occupation_Manual  \
# CustomerID                             -0.008868           0.024769
# Gender                                 -0.013094           0.011222
# MaritalStatus                           0.037294          -0.014242
# HomeOwnerFlag                           0.190383          -0.213904
# NumberCarsOwned                         0.242365          -0.379733
# ...                                          ...                ...
# Occupation_Clerical                    -0.243346          -0.269063
# Occupation_Management                   1.000000          -0.203833
# Occupation_Manual                      -0.203833           1.000000
# Occupation_Professional                -0.132794          -0.146827
# Occupation_Skilled Manual              -0.301325          -0.333169
#
#                            Occupation_Professional  Occupation_Skilled Manual
# CustomerID                               -0.022005                   0.005141
# Gender                                    0.004709                  -0.001308
# MaritalStatus                             0.028880                  -0.035670
# HomeOwnerFlag                             0.224440                  -0.142416
# NumberCarsOwned                           0.203863                  -0.163579
# ...                                            ...                        ...
# Occupation_Clerical                      -0.175290                  -0.397754
# Occupation_Management                    -0.132794                  -0.301325
# Occupation_Manual                        -0.146827                  -0.333169
# Occupation_Professional                   1.000000                  -0.217054
# Occupation_Skilled Manual                -0.217054                   1.000000
#
# [336 rows x 336 columns]
